# %%
# Re-load the dataset after execution state reset
import pandas as pd

file_path = "./extended_smartphone_sales_report.csv"
df = pd.read_csv(file_path)

# Display basic info about the dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        14640 non-null  object
#  1   Product Name                14640 non-null  object
#  2   Units Sold                  14640 non-null  int64
#  3   Price                       14640 non-null  int64
#  4   Competitor Price            14640 non-null  int64
#  5   Stock Available             14640 non-null  int64
#  6   Marketing Spend             14640 non-null  int64
#  7   Holiday/Seasonal Indicator  14640 non-null  int64
#  8   Weather Condition           14640 non-null  object
#  9   Economic Indicator          14640 non-null  float64
#  10  Social Media Trend Score    14640 non-null  int64
#  11  Market Sentiment Score      14640 non-null  float64
#  12  Competitor Activity Score   14640 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.5+ MB
# (None,
#           Date        Product Name  Units Sold  Price  Competitor Price  \
#  0  2023-04-01           iPhone 14           6    906               880
#  1  2023-04-01       iPhone 14 Pro          24    968              1002
#  2  2023-04-01           iPhone 15          10   1268              1224
#  3  2023-04-01       iPhone 15 Pro          11    659               614
#  4  2023-04-01  Samsung Galaxy S22          24   1234              1316
#
#     Stock Available  Marketing Spend  Holiday/Seasonal Indicator  \
#  0              181              278                           1
#  1              302              171                           1
#  2              237              103                           1
#  3              489             1443                           1
#  4              242              498                           1
#
#    Weather Condition  Economic Indicator  Social Media Trend Score  \
#  0            Cloudy            0.931082                        65
#  1            Cloudy            1.032157                         7
#  2            Cloudy            0.600440                        14
#  3            Cloudy            1.049365                        21
#  4             Rainy            1.028686                        97
#
#     Market Sentiment Score  Competitor Activity Score
#  0               -0.104916                          4
#  1               -0.196967                          6
#  2                0.920025                          5
#  3               -0.366109                          5
#  4                0.051699                          2  )

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Convert Date column to datetime format
df["Date"] = pd.to_datetime(df["Date"])

# Extract date-based features
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df["Weekday"] = df["Date"].dt.weekday

# Encode categorical variables
label_encoder = LabelEncoder()
df["Product Name"] = label_encoder.fit_transform(df["Product Name"])
df["Weather Condition"] = label_encoder.fit_transform(df["Weather Condition"])

# Normalize numerical columns
scaler = MinMaxScaler()
num_cols = ["Price", "Competitor Price", "Stock Available", "Marketing Spend",
            "Economic Indicator", "Social Media Trend Score", "Market Sentiment Score", "Competitor Activity Score"]
df[num_cols] = scaler.fit_transform(df[num_cols])

# Drop original Date column as we have extracted features
df.drop(columns=["Date"], inplace=True)

# Display the processed dataset
df.head()
# Out:
#    Product Name  Units Sold     Price  Competitor Price  Stock Available  \
# 0            16           6  0.505421          0.466865         0.291759
# 1            17          24  0.557131          0.557707         0.561247
# 2            18          10  0.807339          0.723008         0.416481
# 3            19          11  0.299416          0.268801         0.977728
# 4             8          24  0.778982          0.791512         0.427617
#
#    Marketing Spend  Holiday/Seasonal Indicator  Weather Condition  \
# 0         0.127234                           1                  0
# 1         0.050751                           1                  0
# 2         0.002144                           1                  0
# 3         0.959971                           1                  0
# 4         0.284489                           1                  1
#
#    Economic Indicator  Social Media Trend Score  Market Sentiment Score  \
# 0            0.431125                  0.656566                0.447599
# 1            0.532223                  0.070707                0.401566
# 2            0.100410                  0.141414                0.960145
# 3            0.549434                  0.212121                0.316983
# 4            0.528750                  0.979798                0.525918
#
#    Competitor Activity Score  Year  Month  Day  Weekday
# 0                   0.444444  2023      4    1        5
# 1                   0.666667  2023      4    1        5
# 2                   0.555556  2023      4    1        5
# 3                   0.555556  2023      4    1        5
# 4                   0.222222  2023      4    1        5

# %%
df.to_csv("preprocessed_smartphone_sales.csv", index=False)

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Generate date range for 3 years (1095 days)
start_date = datetime(2022, 1, 1)
end_date = datetime(2024, 12, 31)
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

# Smartphone models with specifications
smartphones = [
    ("iPhone 14", "6GB", "128GB"),
    ("iPhone 15", "6GB", "256GB"),
    ("Samsung Galaxy S22", "8GB", "128GB"),
    ("Samsung Galaxy S23", "8GB", "256GB"),
    ("Google Pixel 7",  "8GB", "128GB"),
    ("Google Pixel 8",  "8GB", "256GB"),
    ("OnePlus 10 Pro","12GB", "256GB"),
    ("OnePlus 11",  "16GB", "512GB"),
    ("Xiaomi Mi 12",  "8GB", "128GB"),
    ("Xiaomi Mi 13",  "12GB", "256GB"),
    ("Oppo Find X5",  "8GB", "128GB"),
    ("Oppo Find X6", "12GB", "512GB")
]

# Generate sales data
data = []
for date in date_range:
    for name,ram, storage in smartphones:
        units_sold = np.random.randint(5, 200)
        price = np.random.randint(600, 1500)
        competitor_price = price + np.random.randint(-50, 50)
        stock_available = np.random.randint(50, 500)
        marketing_spend = np.random.randint(1000, 20000)
        holiday_season = 1 if date.month in [11, 12] else 0
        weather_condition = np.random.choice([0, 1], p=[0.85, 0.15])
        economic_indicator = np.random.uniform(0.8, 1.2)
        social_media_trend = np.random.uniform(0.5, 1.5)
        market_sentiment = np.random.uniform(0.5, 1.5)
        competitor_activity = np.random.uniform(0.5, 1.5)

        data.append([date, name, ram, storage, units_sold, price, competitor_price,
                     stock_available, marketing_spend, holiday_season, weather_condition,
                     economic_indicator, social_media_trend, market_sentiment, competitor_activity])

# Create DataFrame
columns = ["Date", "Product Name", "RAM", "Memory", "Units Sold", "Price (USD)",
           "Competitor Price", "Stock Available", "Marketing Spend", "Holiday/Season Indicator",
           "Weather Condition", "Economic Indicator", "Social Media Trend Score",
           "Market Sentiment Score", "Competitor Activity Score"]

df = pd.DataFrame(data, columns=columns)

# Save to CSV
df.to_csv("smartphone_sales_3_years.csv", index=False)
print("Dataset saved as smartphone_sales_3_years.csv")
# Out:
# Dataset saved as smartphone_sales_3_years.csv

# %%
# Re-load the dataset after execution state reset
import pandas as pd

file_path = "./smartphone_sales_3_years.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 file_path = "./smartphone_sales_3_years.csv"
# ----> 5 df = pd.read_csv(file_path)
#       6 df.head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './smartphone_sales_3_years.csv'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load dataset
df = pd.read_csv("./smartphone_sales_3_years.csv")

# Convert 'Date' column to datetime format
df["Date"] = pd.to_datetime(df["Date"])

# Handle missing values
for col in df.select_dtypes(include=["number"]).columns:
    df[col] = df[col].fillna(df[col].median())  # Fill missing numerical values with median

for col in df.select_dtypes(include=["object"]).columns:
    df[col] = df[col].fillna(df[col].mode()[0])  # Fill missing categorical values with mode

# Remove duplicates
df = df.drop_duplicates()

# Remove outliers using IQR method
num_cols = df.select_dtypes(include=["number"]).columns
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[num_cols] < (Q1 - 1.5 * IQR)) | (df[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# Normalize numerical features using Min-Max Scaling
scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# Encode categorical variables using One-Hot Encoding
df = pd.get_dummies(df, columns=["Product Name", "RAM", "Memory"], drop_first=True)

# Save preprocessed dataset
df.to_csv("preprocessed_smartphone_sales.csv", index=False)
print("Preprocessed dataset saved as preprocessed_smartphone_sales.csv")
# Out:
# Preprocessed dataset saved as preprocessed_smartphone_sales.csv

# %%
import pandas as pd

file_path = "../data/smartphone_sales_3_years.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#          Date        Product Name  RAM Memory  Units Sold  Price (USD)  \
# 0  2022-01-01           iPhone 14  6GB  128GB         121         1229
# 1  2022-01-01           iPhone 15  6GB  256GB           9         1147
# 2  2022-01-01  Samsung Galaxy S22  8GB  128GB         164          874
# 3  2022-01-01  Samsung Galaxy S23  8GB  256GB          40          628
# 4  2022-01-01      Google Pixel 7  8GB  128GB         182         1360
#
#    Competitor Price  Stock Available  Marketing Spend  \
# 0              1191              216             7196
# 1              1176              292            12616
# 2               872              401            10040
# 3               586              401             5343
# 4              1337              352            10026
#
#    Holiday/Season Indicator  Weather Condition  Economic Indicator  \
# 0                         0                  0            1.141706
# 1                         0                  0            0.963156
# 2                         0                  0            1.056488
# 3                         0                  0            0.847789
# 4                         0                  0            1.030673
#
#    Social Media Trend Score  Market Sentiment Score  Competitor Activity Score
# 0                  0.665271                0.943892                   0.611567
# 1                  1.381480                1.470195                   1.177919
# 2                  1.089368                0.907426                   1.382127
# 3                  0.520334                1.114030                   0.927781
# 4                  0.642926                1.049445                   0.683519

# %%
pip install google-search-results
# Out:
# Collecting google-search-results
#   Using cached google_search_results-2.4.2-py3-none-any.whl
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->google-search-results) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->google-search-results) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->google-search-results) (2025.1.31)
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_trends",
  "q": "Apple iPhone 14 128GB",
  "data_type": "TIMESERIES",
  "api_key": "54689b480842147086ac6f6b033f096ff9a76197e528284d3ee8cbb66e1de587"
}

search = GoogleSearch(params)
results = search.get_dict()
interest_over_time = results['interest_over_time']
timeline_data = interest_over_time['timeline_data']
print(timeline_data)
for values in timeline_data[:1]:
     extracted_value = values['values'][0]['value']
     print(extracted_value)
# Out:
# [{'date': 'Apr 7\u2009–\u200913, 2024', 'timestamp': '1712448000', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '41', 'extracted_value': 41}]}, {'date': 'Apr 14\u2009–\u200920, 2024', 'timestamp': '1713052800', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '44', 'extracted_value': 44}]}, {'date': 'Apr 21\u2009–\u200927, 2024', 'timestamp': '1713657600', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '46', 'extracted_value': 46}]}, {'date': 'Apr 28\u2009–\u2009May 4, 2024', 'timestamp': '1714262400', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '37', 'extracted_value': 37}]}, {'date': 'May 5\u2009–\u200911, 2024', 'timestamp': '1714867200', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '52', 'extracted_value': 52}]}, {'date': 'May 12\u2009–\u200918, 2024', 'timestamp': '1715472000', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '37', 'extracted_value': 37}]}, {'date': 'May 19\u2009–\u200925, 2024', 'timestamp': '1716076800', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '45', 'extracted_value': 45}]}, {'date': 'May 26\u2009–\u2009Jun 1, 2024', 'timestamp': '1716681600', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '40', 'extracted_value': 40}]}, {'date': 'Jun 2\u2009–\u20098, 2024', 'timestamp': '1717286400', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '47', 'extracted_value': 47}]}, {'date': 'Jun 9\u2009–\u200915, 2024', 'timestamp': '1717891200', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '47', 'extracted_value': 47}]}, {'date': 'Jun 16\u2009–\u200922, 2024', 'timestamp': '1718496000', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '50', 'extracted_value': 50}]}, {'date': 'Jun 23\u2009–\u200929, 2024', 'timestamp': '1719100800', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '52', 'extracted_value': 52}]}, {'date': 'Jun 30\u2009–\u2009Jul 6, 2024', 'timestamp': '1719705600', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '41', 'extracted_value': 41}]}, {'date': 'Jul 7\u2009–\u200913, 2024', 'timestamp': '1720310400', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '49', 'extracted_value': 49}]}, {'date': 'Jul 14\u2009–\u200920, 2024', 'timestamp': '1720915200', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '44', 'extracted_value': 44}]}, {'date': 'Jul 21\u2009–\u200927, 2024', 'timestamp': '1721520000', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '49', 'extracted_value': 49}]}, {'date': 'Jul 28\u2009–\u2009Aug 3, 2024', 'timestamp': '1722124800', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '42', 'extracted_value': 42}]}, {'date': 'Aug 4\u2009–\u200910, 2024', 'timestamp': '1722729600', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '37', 'extracted_value': 37}]}, {'date': 'Aug 11\u2009–\u200917, 2024', 'timestamp': '1723334400', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '42', 'extracted_value': 42}]}, {'date': 'Aug 18\u2009–\u200924, 2024', 'timestamp': '1723939200', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '41', 'extracted_value': 41}]}, {'date': 'Aug 25\u2009–\u200931, 2024', 'timestamp': '1724544000', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '35', 'extracted_value': 35}]}, {'date': 'Sep 1\u2009–\u20097, 2024', 'timestamp': '1725148800', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '49', 'extracted_value': 49}]}, {'date': 'Sep 8\u2009–\u200914, 2024', 'timestamp': '1725753600', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '63', 'extracted_value': 63}]}, {'date': 'Sep 15\u2009–\u200921, 2024', 'timestamp': '1726358400', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '50', 'extracted_value': 50}]}, {'date': 'Sep 22\u2009–\u200928, 2024', 'timestamp': '1726963200', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '54', 'extracted_value': 54}]}, {'date': 'Sep 29\u2009–\u2009Oct 5, 2024', 'timestamp': '1727568000', 'values': [{'query': 'Apple iPhone 14 128GB', 'value': '47', 'extracted_value ...
# 41

# %%
print(results["interest_over_time"])
# Out:
# {'timeline_data': [{'date': 'Apr 7\u2009–\u200913, 2024', 'timestamp': '1712448000', 'values': [{'query': 'Samsung Galaxy S22', 'value': '85', 'extracted_value': 85}]}, {'date': 'Apr 14\u2009–\u200920, 2024', 'timestamp': '1713052800', 'values': [{'query': 'Samsung Galaxy S22', 'value': '90', 'extracted_value': 90}]}, {'date': 'Apr 21\u2009–\u200927, 2024', 'timestamp': '1713657600', 'values': [{'query': 'Samsung Galaxy S22', 'value': '97', 'extracted_value': 97}]}, {'date': 'Apr 28\u2009–\u2009May 4, 2024', 'timestamp': '1714262400', 'values': [{'query': 'Samsung Galaxy S22', 'value': '93', 'extracted_value': 93}]}, {'date': 'May 5\u2009–\u200911, 2024', 'timestamp': '1714867200', 'values': [{'query': 'Samsung Galaxy S22', 'value': '86', 'extracted_value': 86}]}, {'date': 'May 12\u2009–\u200918, 2024', 'timestamp': '1715472000', 'values': [{'query': 'Samsung Galaxy S22', 'value': '90', 'extracted_value': 90}]}, {'date': 'May 19\u2009–\u200925, 2024', 'timestamp': '1716076800', 'values': [{'query': 'Samsung Galaxy S22', 'value': '85', 'extracted_value': 85}]}, {'date': 'May 26\u2009–\u2009Jun 1, 2024', 'timestamp': '1716681600', 'values': [{'query': 'Samsung Galaxy S22', 'value': '87', 'extracted_value': 87}]}, {'date': 'Jun 2\u2009–\u20098, 2024', 'timestamp': '1717286400', 'values': [{'query': 'Samsung Galaxy S22', 'value': '85', 'extracted_value': 85}]}, {'date': 'Jun 9\u2009–\u200915, 2024', 'timestamp': '1717891200', 'values': [{'query': 'Samsung Galaxy S22', 'value': '84', 'extracted_value': 84}]}, {'date': 'Jun 16\u2009–\u200922, 2024', 'timestamp': '1718496000', 'values': [{'query': 'Samsung Galaxy S22', 'value': '87', 'extracted_value': 87}]}, {'date': 'Jun 23\u2009–\u200929, 2024', 'timestamp': '1719100800', 'values': [{'query': 'Samsung Galaxy S22', 'value': '81', 'extracted_value': 81}]}, {'date': 'Jun 30\u2009–\u2009Jul 6, 2024', 'timestamp': '1719705600', 'values': [{'query': 'Samsung Galaxy S22', 'value': '92', 'extracted_value': 92}]}, {'date': 'Jul 7\u2009–\u200913, 2024', 'timestamp': '1720310400', 'values': [{'query': 'Samsung Galaxy S22', 'value': '91', 'extracted_value': 91}]}, {'date': 'Jul 14\u2009–\u200920, 2024', 'timestamp': '1720915200', 'values': [{'query': 'Samsung Galaxy S22', 'value': '93', 'extracted_value': 93}]}, {'date': 'Jul 21\u2009–\u200927, 2024', 'timestamp': '1721520000', 'values': [{'query': 'Samsung Galaxy S22', 'value': '92', 'extracted_value': 92}]}, {'date': 'Jul 28\u2009–\u2009Aug 3, 2024', 'timestamp': '1722124800', 'values': [{'query': 'Samsung Galaxy S22', 'value': '91', 'extracted_value': 91}]}, {'date': 'Aug 4\u2009–\u200910, 2024', 'timestamp': '1722729600', 'values': [{'query': 'Samsung Galaxy S22', 'value': '85', 'extracted_value': 85}]}, {'date': 'Aug 11\u2009–\u200917, 2024', 'timestamp': '1723334400', 'values': [{'query': 'Samsung Galaxy S22', 'value': '88', 'extracted_value': 88}]}, {'date': 'Aug 18\u2009–\u200924, 2024', 'timestamp': '1723939200', 'values': [{'query': 'Samsung Galaxy S22', 'value': '92', 'extracted_value': 92}]}, {'date': 'Aug 25\u2009–\u200931, 2024', 'timestamp': '1724544000', 'values': [{'query': 'Samsung Galaxy S22', 'value': '86', 'extracted_value': 86}]}, {'date': 'Sep 1\u2009–\u20097, 2024', 'timestamp': '1725148800', 'values': [{'query': 'Samsung Galaxy S22', 'value': '85', 'extracted_value': 85}]}, {'date': 'Sep 8\u2009–\u200914, 2024', 'timestamp': '1725753600', 'values': [{'query': 'Samsung Galaxy S22', 'value': '84', 'extracted_value': 84}]}, {'date': 'Sep 15\u2009–\u200921, 2024', 'timestamp': '1726358400', 'values': [{'query': 'Samsung Galaxy S22', 'value': '88', 'extracted_value': 88}]}, {'date': 'Sep 22\u2009–\u200928, 2024', 'timestamp': '1726963200', 'values': [{'query': 'Samsung Galaxy S22', 'value': '85', 'extracted_value': 85}]}, {'date': 'Sep 29\u2009–\u2009Oct 5, 2024', 'timestamp': '1727568000', 'values': [{'query': 'Samsung Galaxy S22', 'value': '79', 'extracted_value': 79}]}, {'date': 'Oct 6\u2009–\u200912, 2024', 'timestamp' ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_shopping",
  "q": "iPhone 15 6+256",  # Your search query
  "gl": "us",
  "hl": "en",
  "api_key": "54689b480842147086ac6f6b033f096ff9a76197e528284d3ee8cbb66e1de587"
}

search = GoogleSearch(params)
results = search.get_dict()

# Display all shopping results
shopping_results = results.get("shopping_results", [])
for result in shopping_results[:1]:
    print("Title:", result.get("title"))
    print("Product ID:", result.get("product_id"))  # <== You need this
    print("Price:", result.get("price"))
    print("Link:", result.get("link"))
# Out:
# Title: Apple iPhone 15
# Product ID: 12455355607861195108
# Price: $666.38
# Link: None

# %%
### Feedback

from serpapi import GoogleSearch

API_KEY = "54689b480842147086ac6f6b033f096ff9a76197e528284d3ee8cbb66e1de587"

shopping_params = {
  "engine": "google_shopping",
  "q": "iPhone 15", 
  "gl": "us",
  "hl": "en",
  "api_key": API_KEY
}

search = GoogleSearch(params)
results = search.get_dict()

product_id = ""

# Display all shopping results
shopping_results = results.get("shopping_results", [])
for result in shopping_results[:1]:
    product_id = result.get("product_id")

params = {
  "engine": "google_product",
  "product_id": product_id,
  "reviews": "1",
  "gl": "us",
  "hl": "en",
  "api_key": API_KEY
}

search = GoogleSearch(params)
results = search.get_dict()
reviews_results = results["reviews_results"]
review_array = results["reviews_results"]
content = review_array['reviews']

for review in content:
    print(review['content'])
    print("------")
# Out:
# The Iphone 15 is a disappointment in performance and durability over my old Galaxy A51. The old A51 is a 4G phone that runs the Android OS. It did nothing special but was durable with no screen protector and a simple Incipio 2 piece case. After having the A51 for a few years I decided to upgrade because my employer uses Apple products to communicate. I was also waiting for Apple to stop using proprietary charging cords which seems wasteful and environmentally unfriendly.
#
# I paid extra for shipping which is insulting after a one thousand dollar purchase. The phone arrived and I couldn't connect it to the 5G service or make calls. I had to wait on hold on my old phone as a customer service rep connected new my phone to the Verizon network. Once up and running I put on the same model Incipio case for the Iphone as I had used for the A51. No issues but the Incipio case doesn't protect the camera lenses very well. I had screen protectors ordered but they arrived 2 days later than the phone. In the 2 days of using the Iphone before the screen protectors arrived the screen was scratched while carrying it in my pocket with some change or a key. My A51 lasted it's entire life in my pocket with the same change and keys without a scratch. It was returned to Verizon in almost new condition. The Iphone has been a disappointment in durability in less than a week of owning it.
#
# The OS on the Iphone is different and takes some getting used to but nothing made me say wow this is so much better than the Android OS. I still need all the Microsoft 360 junk to send and receive emails and run reports so nothing stands out as great for the Iphone.
#
# Overall just another handheld mind control device that tracks my every move and monitors my speech for unpopular opinions. In a word, Boring.
# ------
# I purchased my iPhone 15 back in March 2024. I use it for work and it is an essential tool for my job. I take hundreds of photos and videos per day and have to edit them on the spot. Using the programs the phone comes with like "iMovie" and "iPhoto" makes the device really convenient. However, I have to regularly set my phone in front of a high powered fan or stick it in the freezer for at least 5 minutes in order to get it to cool down. Once it heats up, it stops working properly and wont transfer any photos or videos to my computer. This eats up SUCH a big chunk of my day and makes me look really inefficient as a result.
#
# To those looking to use this phone for its powerful processing and photo capabilities, be aware. This phone has caused me WAY more problems than any phone before it. It is not an improvement at all, in my opinion, from the previous phone models. I had an iPhone XR before this one and it worked SOOOO much better.
#
# Besides the overheating issue, I have had other issues with the phone glitching and the pull down from the top of the screen not working. Sometimes apps will just freeze and quit on me. I just find this phone to be extremely frustrating to use. The USBC bullshit is so frustrating too. Its like apple really wants to piss off their customers. At this point, I am angry because I have spent years using and learning the apple products and now its all gone to shit.
# ------
# If you’re thinking of upgrading to an IPhone 16 anytime soon, don’t. The iPhone 15 is not only the most affordable design, but in my opinion, the sleeker, better option. The iPhone 15/iphone 15 plus comes in various pastel colours, the bubblegum pink being my absolute favourite. The camera creates more realistic photos, without the oversaturated pictures that the previous versions of the iPhone carry. It looks exactly how you see the world without a lens. The matte design was definitely a fantastic design! It hides smudges, scratches and fingerprints; Unlike the glossy design that’s been used for years. You can customise your control panel on the iPhone 15, customise your phones layout/colours (including the app icons!), you’ll receive the latest software updates for years to come, and you’ll enjoy making it yours. Lost your phone? No problem ! There’s Find My Iphone, need to write down important information? Great, you have your very own journal that nobody can access other than you as it’s protected by Face ID. You need to unlock your phone with a facemask or set up multiple Face IDs? The iPhone 15 has got you covered. It’s a remarkable piece of technology that will feel/look brand new for years to come. So, again, don’t upgrade. Save yourself the extra money and purchase the iPhone 15. You won’t regret it!
# ------
# As an iPhone 15 user, I can confidently say that this device has exceeded my expectations in almost every way. From its stunning design to its seamless performance, it’s clear Apple has refined the user experience. As someone who loves taking photos, the iPhone 15’s 48MP main camera is a standout feature. Pictures come out sharp, even in low light, and the new automatic focus in portrait mode is a small but impactful improvement. Capturing moments feels effortless, and the results often rival dedicated cameras. Just gave an example.
#
# Recently I have shifted from android to iPhone, and the switch to USB-C has been incredibly convenient and the faster charging is a bonus. It’s a small change that makes a big difference in daily life.
# While the iPhone 15 excels in many areas, battery life has been slightly underwhelming. On days with moderate to heavy usage—streaming videos, gaming, and using GPS—I often find myself needing a recharge before the day is over.
# ------
# My wife needed a new phone and so I decided to look at all the options including a second hand one. I was a little reticent at first in purchasing a 'second hand' phone but I have to say I'm glad I did. Not sure if I was just lucky but the phone arrived in good time and on first inspection there were no visible scratches on the screen or the rear of the phone. The Apple iphone box was well packaged in a bigger box to protect it with a sticky screen protector on and the power cable that looked like it hadn't been used. It powered up without a hitch and booted to the setup screen. I charged the phone fully and decided to let my wife sort out the rest of the configuration as it was supposed to be a surprise. Christmas day came and she completed the setup without a hitch transferring her apps and setup from her old iphone without a problem. On checking the state of the battery it said it was normal and the manufacturer's date was August so the handset was only a few months old. Certainly from my experience I would recommend CEX without hesitation. My wife is very pleased with her 'New' phone.
# ------
# Over the last year I have started to use a Freestyle Libre sensor to monitor my Blood sugar, this monitor connects through Bluetooth every minute using Neare Field Comms, this can be quite a drain on the battery which my old Iphone 12 was having a hard time coping.
# Problem was solved by upgrading to my new Iphone 14 and additionally giving me a lot more features that I am still in the process of learning. I was particularly impressed yesterday with its performance with Google Maps finding a location I was visiting in central London. The speed of reaction was impressive along with the detail. The battery life is so much better than my old Iphone 12 which drained quickly and always had to make sure that I kept a Battery Bank with me, otherwise I would have to rely on my old blood glucose monitor which meant having to prick my fingers to extract blood! Hardly seems any point in taking the Battery Bank out these days with my Iphone 14, still, I have got used to it now.
# I also use my phone regularly to access You Tube for videos particularly on the Ukraine situation and use Audible to listen to books.
# All in all I have made a sound investment in upgrading
# ------
# I was really excited to buy this phone and unfortunately the purchase was completely marred by the delivery by DPD. I paid extra for it to be delivered quickly, so this was extra annoying. The day of delivery(Friday) I could see the van was close by, they took a picture of the back of the apt building and left. I rang JL and they apologised and refunded the extra I paid for a faster delivery(thank you!). I contacted DPD who said they would deliver on Saturday instead, but this time they took a picture of the driveway to the apt...we thought we were winning...getting closer...but no, missed the goal again. Monday, eventually, they managed to make it to my door!
#
# But this was a process that made what should have been nice, super stressful. I was really concerned they were just going to fling it somewhere because by that time, I'd posted on the local fb page to see if others had problems with DPD and the news was not good....
#
# But to the phone itself.... I love it. It is so much better than the old android it replaced. The sound quality is superb, the camera wonderful and I love the portrait mode that blurs everything around the thing you are focusing on. It links up with my iPad for the image gallery which is handy. Charging wise it's really fast and the charge lasts a long time. It's also very quick to respond to commands on it. I picked this one as a bit of a workhorse to last quite a few years, and I think it fits the bill. Ultimately very pleased with the phone but nil points to DPD.
# ------
# I was really excited to buy this phone and unfortunately the purchase was completely marred by the delivery by DPD. I paid extra for it to be delivered quickly, so this was extra annoying. The day of delivery(Friday) I could see the van was close by, they took a picture of the back of the apt building and left. I rang JL and they apologised and refunded the extra I paid for a faster delivery(thank you!). I contacted DPD who said they would deliver on Saturday instead, but this time they took a picture of the driveway to the apt...we thought we were winning...getting closer...but no, missed the goal again. Monday, eventually, they managed to make it to my door!
#
# But this was a process that made what should have been nice, super stressful. I was really concerned they were just going to fling it somewhere because by that time, I'd posted on the local fb page to see if others had problems with DPD and the news was not good....
#
# But to the phone itself.... I love it. It is so much better than the old android it replaced. The sound quality is superb, the camera wonderful and I love the portrait mode that blurs everything around the thing you are focusing on. It links up with my iPad for the image gallery which is handy. Charging wise it's really fast and the charge lasts a long time. It's also very quick to respond to commands on it. I picked this one as a bit of a workhorse to last quite a few years, and I think it fits the bill. Ultimately very pleased with the phone but nil points to DPD.
# ------
# This is my review after having the IPhone 15 blue version 128GB after 1 week.
#
# Firstly I have to say I think the shipping was good. Since I had a strong preference for the blue appearance of the phone over the rest of the colours I was holding out until it came back in stock, as soon as it did, I ordered it and had it 3 days after.
#
# I chose for the phone to be in Grade A condition and it arrived without a single scratch or mark. I was very impressed. It was practically new. I am with Vodafone so since the IPhone was unlocked I had no issues transferring the SIM from my prior phone. I was also slightly concerned about transferring my information from Android to IPhone but thankfully there was no issues there either, it was all very smooth. Lastly, I checked the battery capacity and cycle count of the phone only to be amazed that there were no prior charges and 100% capacity. It runs very smoothly and I am thoroughly enjoying it. I will definitely be buying from CEX again, I cant recommend it enough. As of writing this review I have not encountered a single problem.
# ------
# There was an improvement in that the picture I used from my wallpaper was full screen as opposed to just part of the screen. Otherwise, everything pretty much stayed the same although, I can’t really tell because the first iPhone 15 I got was defective so I can’t really judge things because I don’t know if they are working 100%. But I did notice and it may be a defect with the phone I’m still using & haven’t sent back yet because the delivery was delayed twice so far. Anyhow gets incredibly hot whenever music is played. It never did on my previous iPhone. But I don’t know if this is a defect or is something with the new operating system or new hardware, but as we speak, it is cooling off and has probably gone down, about 25° so far. I’m talking it gets almost too hot to touch and this is only ever when I play Apple Music. Not when I’m scrolling through social media, making video calls, using the phone or in any other kind of capacity. It is just with the Apple Music. But then again the issues I’m having are largely with the speakers and sound so, The issue I’m having with it heating up whenever I use Apple Music may be part of the defect. IDK.
# ------
